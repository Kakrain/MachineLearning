# %% [markdown]
# # Assignment 8
# ## Due June 19th
# ### names:

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from numpy import linalg as LA
from sklearn.datasets import make_classification
from sklearn.gaussian_process.kernels import RBF
from mpl_toolkits.mplot3d import Axes3D


np.random.seed(42)

# %% [markdown]
# ## Exercise 1

# %%
def get_cicle_data(n=50, r=1):
    
    np.random.seed(n)
    
    thetas = np.random.uniform(0, 2*np.pi, n)
    data = np.array([r * np.sin(thetas), r * np.cos(thetas)]).T + np.random.normal(scale=1/8, size=(n,2))
    
    return data

# %%
def get_gaussian_data(n, mean=0.0, sigma=1.0):
    
    np.random.seed(n)
    
    data = np.random.normal(loc=mean, scale=sigma, size=(n,2))
    
    return data

# %% [markdown]
# ### a)

# %%
data, labels = make_classification(n_samples=25, n_features=2, n_informative=2, n_redundant=0, n_repeated=0, n_classes=2, n_clusters_per_class=1, random_state=42, class_sep=0)

fig = plt.figure()
x1=data[labels==1]
x0=data[labels!=1]
plt.scatter(x1[:, 0], x1[:, 1], c='red',label="y=1");
plt.scatter(x0[:, 0], x0[:, 1], c='blue',label="y=0");
plt.legend(bbox_to_anchor=(0.8, 1), loc=2, borderaxespad=0.)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# ### b)

# %%
def PCA(xs, l):
    n=len(xs)
    d=len(xs[0])
    m=np.mean(xs)
    xm=np.add(xs,-m)
    C=np.matmul(np.transpose(xm),xm)
    w,v=np.linalg.eig(C)
    sortind=np.argsort(w)
    wl=np.sort(w)[l:]
    vl=np.transpose(np.delete(np.transpose(v),sortind[:l],axis=0))
    xl=np.transpose(np.delete(np.transpose(xm),sortind[:l],axis=0))
    y=np.matmul(vl,np.transpose(xl))
    P=np.matmul(vl,np.transpose(vl))
    z=np.transpose(np.matmul(P,np.transpose(xm))+m)
    return (y,z,np.flip(np.sort(w),axis=0),wl)

# %% [markdown]
# ### c)

# %%
y,z,w,wl=PCA(data,1)
fig = plt.figure()
plt.scatter(data[:, 0], data[:, 1],marker='o', c='red',label="data");
plt.scatter(z[:, 0], z[:, 1],marker='x', c='blue',label="z");
for i in range(0,len(data)):
    plt.plot([data[i,0],z[i,0]],[data[i,1],z[i,1]])
plt.legend(bbox_to_anchor=(0.8, 1), loc=2, borderaxespad=0.)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# ### d)

# %%
a = get_cicle_data(25, 1)
b = get_cicle_data(25, 3)
data = np.concatenate([a,b])
labels = np.concatenate([np.zeros(a.shape[0]), np.ones(b.shape[0])])

fig = plt.figure()
x1=data[labels==1]
x0=data[labels!=1]
plt.scatter(x1[:, 0], x1[:, 1], c='red',label="y=1");
plt.scatter(x0[:, 0], x0[:, 1], c='blue',label="y=0");
plt.legend(bbox_to_anchor=(0.8, 1), loc=2, borderaxespad=0.)
plt.show()

y,z,w,wl=PCA(data,1)
fig = plt.figure()
plt.scatter(data[:, 0], data[:, 1],marker='o', c='red',label="data");
plt.scatter(z[:, 0], z[:, 1],marker='x', c='blue',label="z");
for i in range(0,len(data)):
    plt.plot([data[i,0],z[i,0]],[data[i,1],z[i,1]])
plt.legend(bbox_to_anchor=(0.8, 1), loc=2, borderaxespad=0.)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# ### e)

# %%
data, labels = make_classification(n_samples=25, n_features=2, n_informative=2, n_redundant=0, n_repeated=0, n_classes=2, n_clusters_per_class=1, random_state=42, class_sep=0)
data[:, 0] = 100 * data[:, 0] 
fig = plt.figure()
x1=data[labels==1]
x0=data[labels!=1]
plt.scatter(x1[:, 0], x1[:, 1], c='red',label="y=1");
plt.scatter(x0[:, 0], x0[:, 1], c='blue',label="y=0");
plt.legend(bbox_to_anchor=(0.8, 1), loc=2, borderaxespad=0.)
plt.show()
y,z,w,wl=PCA(data,1)
fig = plt.figure()
plt.scatter(data[:, 0], data[:, 1],marker='o', c='red',label="data");
plt.scatter(z[:, 0], z[:, 1],marker='x', c='blue',label="z");
for i in range(0,len(data)):
    plt.plot([data[i,0],z[i,0]],[data[i,1],z[i,1]])
plt.legend(bbox_to_anchor=(0.8, 1), loc=2, borderaxespad=0.)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# # Exercise 2)

# %%
data = np.concatenate([get_cicle_data(100, 2),
                       get_cicle_data(100, 4),
                       get_cicle_data(100, 6)])

labels = np.concatenate([np.zeros(100),
                         np.ones(100),
                         2 * np.ones(100)])

# %% [markdown]
# ### a)

# %%
fig = plt.figure()
color = ['orange' if l == 1 else 'red' if l == 2 else 'b' for l in labels]
plt.scatter(data[:, 0], data[:, 1], c=color)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### b)

# %%
def kernel_PCA(xs, kernel, l=2):
    
    pass

# %% [markdown]
# ### c)

# %% [markdown]
# ### d)
